# %%
import os
import random
import numpy as np
import nibabel as nib
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.cuda.amp import GradScaler
import matplotlib.pyplot as plt

# %%
data_root ="C:\\Users\\ASUS\\Desktop\\liver_seg\\data" 
images_dir = os.path.join(data_root, "images")  
labels_dir = os.path.join(data_root, "labels")

# %%
patch_size = (96,160,160)  
batch_size = 1
num_epochs = 15 
num_train_steps_per_epoch = 100 
num_classes = 3            
base_lr = 1e-3

# %%
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed_all(42)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def load_nifti(path):
    nii = nib.load(path)
    vol = nii.get_fdata().astype(np.float32) 
    if vol.ndim == 3:
        if vol.shape[0] != vol.shape[1] and vol.shape[0] != vol.shape[2]:
            vol = np.transpose(vol, (2, 0, 1))
    return vol

# %%
def normalize_volume(vol):
    non_zero = vol[vol > 0]
    if non_zero.size > 0:
        m = non_zero.mean()
        s = non_zero.std() + 1e-8
        vol = (vol - m) / s
    else:
        vol = (vol - vol.mean()) / (vol.std() + 1e-8)
    return vol

# %%
image_files = sorted([f for f in os.listdir(images_dir) if f.endswith(".nii")])
label_files = sorted([f for f in os.listdir(labels_dir) if f.endswith(".nii")])

# %%
len(image_files)
# Out:
# 123

# %%
len(label_files)
# Out:
# 123

# %%
pairs = []
for img_name, lbl_name in zip(image_files, label_files):
    img_path = os.path.join(images_dir, img_name)
    lbl_path = os.path.join(labels_dir, lbl_name)
    pairs.append((img_path, lbl_path))

# %%
pairs[0]
# Out:
# ('C:\\Users\\ASUS\\Desktop\\liver_seg\\data\\images\\liver_0.nii',
#  'C:\\Users\\ASUS\\Desktop\\liver_seg\\data\\labels\\liver_0.nii')

# %%
num_total = len(pairs)
num_train = int(0.8 * num_total)
indices = list(range(num_total))
random.shuffle(indices)

# %%
train_idx = indices[:num_train]
val_idx   = indices[num_train:]

# %%
train_pairs = [pairs[i] for i in train_idx]
val_pairs   = [pairs[i] for i in val_idx]

# %%
len(train_pairs)
# Out:
# 98

# %%
train_images = []
train_labels = []

for img_path, lbl_path in train_pairs:
    img = load_nifti(img_path)
    lbl = load_nifti(lbl_path)
    img = normalize_volume(img)
    lbl = lbl.astype(np.int64)
    train_images.append(img)
    train_labels.append(lbl)

# %%
len(train_images)
# Out:
# 98

# %%
val_images = []
val_labels = []

for img_path, lbl_path in val_pairs:
    img = load_nifti(img_path)
    lbl = load_nifti(lbl_path)
    img = normalize_volume(img)
    lbl = lbl.astype(np.int64)
    val_images.append(img)
    val_labels.append(lbl)

# %%
len(val_images)
# Out:
# 25

# %%
train_images[0].shape
# Out:
# (187, 187, 229)

# %%
np.unique(train_labels[0])
# Out:
# array([0, 1, 2])

# %%
def get_random_patch(img, lbl, patch_size, min_dim=16):
    D, H, W = img.shape
    pd_t, ph_t, pw_t = patch_size

    pd = min(pd_t, D)
    ph = min(ph_t, H)
    pw = min(pw_t, W)

    tumor_vox = np.argwhere(lbl == 2)
    liver_vox = np.argwhere(lbl == 1)

    if tumor_vox.size > 0 and random.random() < 0.7:
    # 70% of the time if tumor exists → center on tumor
        cz, cy, cx = tumor_vox[random.randint(0, len(tumor_vox) - 1)]
    elif liver_vox.size > 0:
        cz, cy, cx = liver_vox[random.randint(0, len(liver_vox) - 1)]
    else:
        cz, cy, cx = D // 2, H // 2, W // 2

    z1 = cz - pd // 2
    y1 = cy - ph // 2
    x1 = cx - pw // 2
    z1 = max(0, min(z1, D - pd))
    y1 = max(0, min(y1, H - ph))
    x1 = max(0, min(x1, W - pw))
    z1, y1, x1 = int(z1), int(y1), int(x1)
    img_patch = img[z1:z1 + pd, y1:y1 + ph, x1:x1 + pw]
    lbl_patch = lbl[z1:z1 + pd, y1:y1 + ph, x1:x1 + pw]


    cd, ch, cw = img_patch.shape
    pad_d = max(min_dim - cd, 0)
    pad_h = max(min_dim - ch, 0)
    pad_w = max(min_dim - cw, 0)

    if pad_d > 0 or pad_h > 0 or pad_w > 0:
        pd0 = pad_d // 2
        pd1 = pad_d - pd0
        ph0 = pad_h // 2
        ph1 = pad_h - ph0
        pw0 = pad_w // 2
        pw1 = pad_w - pw0
        img_patch = np.pad(img_patch, ((pd0, pd1), (ph0, ph1), (pw0, pw1)), mode="constant", constant_values=0)
        lbl_patch = np.pad(lbl_patch, ((pd0, pd1), (ph0, ph1), (pw0, pw1)), mode="constant", constant_values=0)


    img_patch = img_patch[np.newaxis, ...]
    img_tensor = torch.from_numpy(img_patch).float()
    lbl_tensor = torch.from_numpy(lbl_patch).long()
    return img_tensor, lbl_tensor

# %%
def train_batch_generator(images, labels, patch_size, batch_size):
    while True:
        batch_imgs = []
        batch_lbls = []
        for _ in range(batch_size):
            idx = random.randint(0, len(images) - 1)
            img = images[idx]
            lbl = labels[idx]
            p_img, p_lbl = get_random_patch(img, lbl, patch_size)
            batch_imgs.append(p_img)
            batch_lbls.append(p_lbl)
        yield torch.stack(batch_imgs), torch.stack(batch_lbls)

# %%
train_gen = train_batch_generator(train_images, train_labels, patch_size, batch_size)

# %%
class DoubleConv3D(nn.Module):
    def __init__(self, in_ch, out_ch):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv3d(in_ch, out_ch, 3, padding=1),
            nn.InstanceNorm3d(out_ch),
            nn.ReLU(inplace=True),
            nn.Conv3d(out_ch, out_ch, 3, padding=1),
            nn.InstanceNorm3d(out_ch),
            nn.ReLU(inplace=True),
        )

    def forward(self, x):
        return self.conv(x)

# %%
class UNet3D(nn.Module):
    def __init__(self, in_channels=1, num_classes=3, base_ch=16):
        super().__init__()
        self.enc1 = DoubleConv3D(in_channels, base_ch)
        self.enc2 = DoubleConv3D(base_ch, base_ch * 2)
        self.enc3 = DoubleConv3D(base_ch * 2, base_ch * 4)
        self.enc4 = DoubleConv3D(base_ch * 4, base_ch * 8)

        self.pool = nn.MaxPool3d(2)

        self.bottleneck = DoubleConv3D(base_ch * 8, base_ch * 16)

        self.up4 = nn.ConvTranspose3d(base_ch * 16, base_ch * 8, 2, 2)
        self.dec4 = DoubleConv3D(base_ch * 16, base_ch * 8)

        self.up3 = nn.ConvTranspose3d(base_ch * 8, base_ch * 4, 2, 2)
        self.dec3 = DoubleConv3D(base_ch * 8, base_ch * 4)

        self.up2 = nn.ConvTranspose3d(base_ch * 4, base_ch * 2, 2, 2)
        self.dec2 = DoubleConv3D(base_ch * 4, base_ch * 2)

        self.up1 = nn.ConvTranspose3d(base_ch * 2, base_ch, 2, 2)
        self.dec1 = DoubleConv3D(base_ch * 2, base_ch)

        self.out_conv = nn.Conv3d(base_ch, num_classes, 1)

    def forward(self, x):
        e1 = self.enc1(x)
        e2 = self.enc2(self.pool(e1))
        e3 = self.enc3(self.pool(e2))
        e4 = self.enc4(self.pool(e3))

        b = self.bottleneck(self.pool(e4))

        d4 = self.up4(b)
        if d4.shape[2:] != e4.shape[2:]:
            d4 = F.interpolate(d4, size=e4.shape[2:], mode="trilinear", align_corners=False)
        d4 = self.dec4(torch.cat([d4, e4], dim=1))

        d3 = self.up3(d4)
        if d3.shape[2:] != e3.shape[2:]:
            d3 = F.interpolate(d3, size=e3.shape[2:], mode="trilinear", align_corners=False)
        d3 = self.dec3(torch.cat([d3, e3], dim=1))

        d2 = self.up2(d3)
        if d2.shape[2:] != e2.shape[2:]:
            d2 = F.interpolate(d2, size=e2.shape[2:], mode="trilinear", align_corners=False)
        d2 = self.dec2(torch.cat([d2, e2], dim=1))

        d1 = self.up1(d2)
        if d1.shape[2:] != e1.shape[2:]:
            d1 = F.interpolate(d1, size=e1.shape[2:], mode="trilinear", align_corners=False)
        d1 = self.dec1(torch.cat([d1, e1], dim=1))

        out = self.out_conv(d1)
        return out

# %%
def dice_loss_multi(logits, targets, num_classes, eps=1e-6):
    probs = F.softmax(logits, dim=1)
    one_hot = F.one_hot(targets, num_classes=num_classes)  
    one_hot = one_hot.permute(0, 4, 1, 2, 3).float()     
    dims = (0, 2, 3, 4)
    intersection = torch.sum(probs * one_hot, dims)
    union = torch.sum(probs + one_hot, dims)
    dice = (2 * intersection + eps) / (union + eps)
    return 1 - dice[1:].mean()

# %%
model = UNet3D(in_channels=1, num_classes=num_classes, base_ch=16).to(device)
dummy = torch.randn(1, 1, *patch_size).to(device)
with torch.no_grad():
    out = model(dummy)

# %%
out.shape
# Out:
# torch.Size([1, 3, 96, 160, 160])

# %%
ce_weights = torch.tensor([0.2, 0.4, 0.4], device=device)
ce_loss_fn = nn.CrossEntropyLoss(weight=ce_weights)
optimizer = torch.optim.AdamW(model.parameters(), lr=base_lr)
scaler = GradScaler()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_12060\2496162686.py:4: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()

# %%
def train_one_epoch(epoch):
    model.train()
    total_ce = 0.0
    total_dice = 0.0
    for step in range(num_train_steps_per_epoch):
        imgs, lbls = next(train_gen)  
        imgs = imgs.to(device)
        lbls = lbls.to(device)
        optimizer.zero_grad(set_to_none=True)

        with torch.cuda.amp.autocast(enabled=(device.type == "cuda")):
            logits = model(imgs)
            loss_ce = ce_loss_fn(logits, lbls)
            loss_dice = dice_loss_multi(logits, lbls, num_classes)
            loss = loss_ce + loss_dice

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        total_ce += loss_ce.item()
        total_dice += loss_dice.item()
        if step % 10 == 0:
            print(f"[Epoch {epoch} Step {step}] CE: {loss_ce.item():.4f}, DiceLoss: {loss_dice.item():.4f}")

    avg_ce = total_ce / num_train_steps_per_epoch
    avg_dice = total_dice / num_train_steps_per_epoch
    print(f"Epoch {epoch} TRAIN — CE: {avg_ce:.4f}, DiceLoss: {avg_dice:.4f}")

# %% [markdown]
# class1: liver
#
# class2: tumor

# %%
@torch.no_grad()
def validate(epoch, num_val_samples=20):
    model.eval()
    liver_dice_sum = 0.0
    tumor_dice_sum = 0.0
    liver_count = 0
    tumor_count = 0
    for _ in range(num_val_samples):
        idx = random.randint(0, len(val_images) - 1)
        img = val_images[idx]
        lbl = val_labels[idx]
        p_img, p_lbl = get_random_patch(img, lbl, patch_size)
        p_img = p_img.unsqueeze(0).to(device)   
        p_lbl = p_lbl.unsqueeze(0).to(device)   
        with torch.cuda.amp.autocast(enabled=(device.type == "cuda")):
            logits = model(p_img)
        preds = logits.argmax(dim=1)         
        pred_b = preds[0]
        lbl_b  = p_lbl[0]

        # class1
        pred_liver = (pred_b == 1)
        lbl_liver  = (lbl_b == 1)
        denom_liver = pred_liver.sum() + lbl_liver.sum()
        if denom_liver > 0:
            inter_liver = (pred_liver & lbl_liver).sum()
            dice_liver = (2.0 * inter_liver.float() / denom_liver.float()).item()
            liver_dice_sum += dice_liver
            liver_count += 1

        # class2
        pred_tumor = (pred_b == 2)
        lbl_tumor  = (lbl_b == 2)
        denom_tumor = pred_tumor.sum() + lbl_tumor.sum()
        if denom_tumor > 0:
            inter_tumor = (pred_tumor & lbl_tumor).sum()
            dice_tumor = (2.0 * inter_tumor.float() / denom_tumor.float()).item()
            tumor_dice_sum += dice_tumor
            tumor_count += 1

    avg_liver = liver_dice_sum / liver_count if liver_count > 0 else 0.0
    avg_tumor = tumor_dice_sum / tumor_count if tumor_count > 0 else 0.0

    print(f"Epoch {epoch} VAL — liver Dice: {avg_liver:.4f}, tumor Dice: {avg_tumor:.4f}")
    return avg_liver, avg_tumor

# %%
best_val_score = -1.0

# %%
for epoch in range(1, num_epochs + 1):
    train_one_epoch(epoch)
    avg_liver, avg_tumor = validate(epoch)
    print(f"Epoch {epoch} — liver Dice: {avg_liver:.4f},tumor Dice:{avg_tumor:.4f}")
    score = (avg_liver + avg_tumor) / 2.0
    print(f"Epoch {epoch} mean Dice (liver+tumor): {score:.4f}")

    if score > best_val_score:
        best_val_score = score
        torch.save(model.state_dict(), "best_unet3d_liver_tumor.pth")
        print("best_val_score:",best_val_score)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_12060\875285598.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=(device.type == "cuda")):
# [Epoch 1 Step 0] CE: 1.2751, DiceLoss: 0.9772
# [Epoch 1 Step 10] CE: 1.0756, DiceLoss: 0.9029
# [Epoch 1 Step 20] CE: 0.9195, DiceLoss: 0.8882
# [Epoch 1 Step 30] CE: 0.7862, DiceLoss: 0.8291
# [Epoch 1 Step 40] CE: 0.8798, DiceLoss: 0.9339
# [Epoch 1 Step 50] CE: 0.6719, DiceLoss: 0.7601
# [Epoch 1 Step 60] CE: 0.6838, DiceLoss: 0.8731
# [Epoch 1 Step 70] CE: 0.6505, DiceLoss: 0.8800
# [Epoch 1 Step 80] CE: 0.6768, DiceLoss: 0.9278
# [Epoch 1 Step 90] CE: 0.5855, DiceLoss: 0.8040
# Epoch 1 TRAIN — CE: 0.7859, DiceLoss: 0.8774
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_12060\2935529778.py:15: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=(device.type == "cuda")):
# Epoch 1 VAL — liver Dice: 0.7529, tumor Dice: 0.0000
# Epoch 1 — liver Dice: 0.7529,tumor Dice:0.0000
# Epoch 1 mean Dice (liver+tumor): 0.3765
# best_val_score: 0.3764700435101986
# [Epoch 2 Step 0] CE: 0.5312, DiceLoss: 0.7319
# [Epoch 2 Step 10] CE: 0.6177, DiceLoss: 0.9295
# [Epoch 2 Step 20] CE: 0.4996, DiceLoss: 0.8576
# [Epoch 2 Step 30] CE: 0.4598, DiceLoss: 0.8420
# [Epoch 2 Step 40] CE: 0.3804, DiceLoss: 0.8199
# [Epoch 2 Step 50] CE: 0.3910, DiceLoss: 0.8570
# [Epoch 2 Step 60] CE: 0.3175, DiceLoss: 0.7306
# [Epoch 2 Step 70] CE: 0.3870, DiceLoss: 0.7049
# [Epoch 2 Step 80] CE: 0.2963, DiceLoss: 0.7799
# [Epoch 2 Step 90] CE: 0.2710, DiceLoss: 0.7939
# Epoch 2 TRAIN — CE: 0.4127, DiceLoss: 0.8123
# Epoch 2 VAL — liver Dice: 0.8285, tumor Dice: 0.0000
# Epoch 2 — liver Dice: 0.8285,tumor Dice:0.0000
# Epoch 2 mean Dice (liver+tumor): 0.4142
# best_val_score: 0.4142269916832447
# [Epoch 3 Step 0] CE: 0.2671, DiceLoss: 0.7759
# [Epoch 3 Step 10] CE: 0.2736, DiceLoss: 0.7848
# [Epoch 3 Step 20] CE: 0.2863, DiceLoss: 0.8501
# [Epoch 3 Step 30] CE: 0.2527, DiceLoss: 0.7946
# [Epoch 3 Step 40] CE: 0.2522, DiceLoss: 0.7695
# [Epoch 3 Step 50] CE: 0.1991, DiceLoss: 0.7917
# [Epoch 3 Step 60] CE: 0.1986, DiceLoss: 0.7697
# [Epoch 3 Step 70] CE: 0.2044, DiceLoss: 0.7512
# [Epoch 3 Step 80] CE: 0.2170, DiceLoss: 0.7041
# [Epoch 3 Step 90] CE: 0.2051, DiceLoss: 0.7024
# Epoch 3 TRAIN — CE: 0.2439, DiceLoss: 0.7447
# Epoch 3 VAL — liver Dice: 0.8707, tumor Dice: 0.0000
# Epoch 3 — liver Dice: 0.8707,tumor Dice:0.0000
# Epoch 3 mean Dice (liver+tumor): 0.4354
# best_val_score: 0.43535560369491577
# [Epoch 4 Step 0] CE: 0.1419, DiceLoss: 0.6699
# [Epoch 4 Step 10] CE: 0.2503, DiceLoss: 0.7286
# [Epoch 4 Step 20] CE: 0.2421, DiceLoss: 0.7224
# [Epoch 4 Step 30] CE: 0.1812, DiceLoss: 0.6685
# [Epoch 4 Step 40] CE: 0.1209, DiceLoss: 0.6547
# [Epoch 4 Step 50] CE: 0.1263, DiceLoss: 0.6727
# [Epoch 4 Step 60] CE: 0.1352, DiceLoss: 0.6651
# [Epoch 4 Step 70] CE: 0.2662, DiceLoss: 0.5901
# [Epoch 4 Step 80] CE: 0.1622, DiceLoss: 0.6261
# [Epoch 4 Step 90] CE: 0.1035, DiceLoss: 0.6604
# Epoch 4 TRAIN — CE: 0.1745, DiceLoss: 0.6795
# Epoch 4 VAL — liver Dice: 0.7405, tumor Dice: 0.0000
# Epoch 4 — liver Dice: 0.7405,tumor Dice:0.0000
# Epoch 4 mean Dice (liver+tumor): 0.3702
# [Epoch 5 Step 0] CE: 0.1462, DiceLoss: 0.6693
# [Epoch 5 Step 10] CE: 0.2840, DiceLoss: 0.8019
# [Epoch 5 Step 20] CE: 0.2007, DiceLoss: 0.6929
# [Epoch 5 Step 30] CE: 0.1353, DiceLoss: 0.7000
# [Epoch 5 Step 40] CE: 0.1269, DiceLoss: 0.6816
# [Epoch 5 Step 50] CE: 0.0988, DiceLoss: 0.6597
# [Epoch 5 Step 60] CE: 0.0947, DiceLoss: 0.6374
# [Epoch 5 Step 70] CE: 0.1902, DiceLoss: 0.6579
# [Epoch 5 Step 80] CE: 0.1541, DiceLoss: 0.6770
# [Epoch 5 Step 90] CE: 0.2074, DiceLoss: 0.7955
# Epoch 5 TRAIN — CE: 0.1443, DiceLoss: 0.6508
# Epoch 5 VAL — liver Dice: 0.9018, tumor Dice: 0.0000
# Epoch 5 — liver Dice: 0.9018,tumor Dice:0.0000
# Epoch 5 mean Dice (liver+tumor): 0.4509
# best_val_score: 0.4508902296423912
# [Epoch 6 Step 0] CE: 0.1014, DiceLoss: 0.6677
# [Epoch 6 Step 10] CE: 0.2572, DiceLoss: 0.8682
# [Epoch 6 Step 20] CE: 0.1085, DiceLoss: 0.6644
# [Epoch 6 Step 30] CE: 0.0697, DiceLoss: 0.5988
# [Epoch 6 Step 40] CE: 0.0829, DiceLoss: 0.6698
# [Epoch 6 Step 50] CE: 0.0801, DiceLoss: 0.6398
# [Epoch 6 Step 60] CE: 0.0659, DiceLoss: 0.6092
# [Epoch 6 Step 70] CE: 0.0662, DiceLoss: 0.6220
# [Epoch 6 Step 80] CE: 0.0627, DiceLoss: 0.5880
# [Epoch 6 Step 90] CE: 0.0567, DiceLoss: 0.5834
# Epoch 6 TRAIN — CE: 0.1231, DiceLoss: 0.6219
# Epoch 6 VAL — liver Dice: 0.9110, tumor Dice: 0.0000
# Epoch 6 — liver Dice: 0.9110,tumor Dice:0.0000
# Epoch 6 mean Dice (liver+tumor): 0.4555
# best_val_score: 0.45551046133041384
# [Epoch 7 Step 0] CE: 0.1188, DiceLoss: 0.5562
# [Epoch 7 Step 10] CE: 0.0525, DiceLoss: 0.5772
# [Epoch 7 Step 20] CE: 0.0708, DiceLoss: 0.6148
# [Epoch 7 Step 30] CE: 0.0525, DiceLoss: 0.5699
# [Epoch 7 Step 40] CE: 0.0764, DiceLoss: 0.6037
# [Epoch 7 Step 50] CE: 0.0625, DiceLoss: 0.6077
# [Epoch 7 Step 60] CE: 0.0972, DiceLoss: 0.6358
# [Epoch 7 Step 70] CE: 0.0511, DiceLoss: 0.5723
# [Epoch 7 Step 80] CE: 0.0558, DiceLoss: 0.5780
# [Epoch 7 Step 90] CE: 0.0691, DiceLoss: 0.5412
# Epoch 7 TRAIN — CE: 0.1034, DiceLoss: 0.6011
# Epoch 7 VAL — liver Dice: 0.8327, tumor Dice: 0.0000
# Epoch 7 — liver Dice: 0.8327,tumor Dice:0.0000
# Epoch 7 mean Dice (liver+tumor): 0.4163
# [Epoch 8 Step 0] CE: 0.0747, DiceLoss: 0.5535
# [Epoch 8 Step 10] CE: 0.0789, DiceLoss: 0.6374
# [Epoch 8 Step 20] CE: 0.0765, DiceLoss: 0.6055
# [Epoch 8 Step 30] CE: 0.0478, DiceLoss: 0.5688
# [Epoch 8 Step 40] CE: 0.0405, DiceLoss: 0.5569
# [Epoch 8 Step 50] CE: 0.1270, DiceLoss: 0.6744
# [Epoch 8 Step 60] CE: 0.0860, DiceLoss: 0.5825
# [Epoch 8 Step 70] CE: 0.2566, DiceLoss: 0.5850
# [Epoch 8 Step 80] CE: 0.1375, DiceLoss: 0.6200
# [Epoch 8 Step 90] CE: 0.0645, DiceLoss: 0.5997
# Epoch 8 TRAIN — CE: 0.0899, DiceLoss: 0.5926
# Epoch 8 VAL — liver Dice: 0.9087, tumor Dice: 0.0000
# Epoch 8 — liver Dice: 0.9087,tumor Dice:0.0000
# Epoch 8 mean Dice (liver+tumor): 0.4544
# [Epoch 9 Step 0] CE: 0.1528, DiceLoss: 0.6035
# [Epoch 9 Step 10] CE: 0.0799, DiceLoss: 0.6031
# [Epoch 9 Step 20] CE: 0.0541, DiceLoss: 0.5848
# [Epoch 9 Step 30] CE: 0.0450, DiceLoss: 0.5790
# [Epoch 9 Step 40] CE: 0.1257, DiceLoss: 0.5879
# [Epoch 9 Step 50] CE: 0.0400, DiceLoss: 0.5918
# [Epoch 9 Step 60] CE: 0.1597, DiceLoss: 0.5858
# [Epoch 9 Step 70] CE: 0.0336, DiceLoss: 0.5568
# [Epoch 9 Step 80] CE: 0.2543, DiceLoss: 0.6550
# [Epoch 9 Step 90] CE: 0.0374, DiceLoss: 0.5453
# Epoch 9 TRAIN — CE: 0.0853, DiceLoss: 0.5829
# Epoch 9 VAL — liver Dice: 0.9210, tumor Dice: 0.0113
# Epoch 9 — liver Dice: 0.9210,tumor Dice:0.0113
# Epoch 9 mean Dice (liver+tumor): 0.4662
# best_val_score: 0.46615428187069485
# [Epoch 10 Step 0] CE: 0.0378, DiceLoss: 0.5505
# [Epoch 10 Step 10] CE: 0.0726, DiceLoss: 0.5281
# [Epoch 10 Step 20] CE: 0.0321, DiceLoss: 0.5647
# [Epoch 10 Step 30] CE: 0.1169, DiceLoss: 0.5866
# [Epoch 10 Step 40] CE: 0.0540, DiceLoss: 0.5811
# [Epoch 10 Step 50] CE: 0.0604, DiceLoss: 0.5562
# [Epoch 10 Step 60] CE: 0.0485, DiceLoss: 0.5825
# [Epoch 10 Step 70] CE: 0.0612, DiceLoss: 0.5448
# [Epoch 10 Step 80] CE: 0.0390, DiceLoss: 0.5548
# [Epoch 10 Step 90] CE: 0.0756, DiceLoss: 0.5850
# Epoch 10 TRAIN — CE: 0.0846, DiceLoss: 0.5836
# Epoch 10 VAL — liver Dice: 0.8864, tumor Dice: 0.0000
# Epoch 10 — liver Dice: 0.8864,tumor Dice:0.0000
# Epoch 10 mean Dice (liver+tumor): 0.4432
# [Epoch 11 Step 0] CE: 0.1295, DiceLoss: 0.5775
# [Epoch 11 Step 10] CE: 0.0446, DiceLoss: 0.5669
# [Epoch 11 Step 20] CE: 0.1779, DiceLoss: 0.5829
# [Epoch 11 Step 30] CE: 0.1561, DiceLoss: 0.5476
# [Epoch 11 Step 40] CE: 0.1883, DiceLoss: 0.5861
# [Epoch 11 Step 50] CE: 0.0428, DiceLoss: 0.5469
# [Epoch 11 Step 60] CE: 0.1707, DiceLoss: 0.5846
# [Epoch 11 Step 70] CE: 0.0400, DiceLoss: 0.5511
# [Epoch 11 Step 80] CE: 0.0413, DiceLoss: 0.5436
# [Epoch 11 Step 90] CE: 0.0625, DiceLoss: 0.5959
# Epoch 11 TRAIN — CE: 0.0861, DiceLoss: 0.5684
# Epoch 11 VAL — liver Dice: 0.8814, tumor Dice: 0.0000
# Epoch 11 — liver Dice: 0.8814,tumor Dice:0.0000
# Epoch 11 mean Dice (liver+tumor): 0.4407
# [Epoch 12 Step 0] CE: 0.0635, DiceLoss: 0.5530
# [Epoch 12 Step 10] CE: 0.0735, DiceLoss: 0.6312
# [Epoch 12 Step 20] CE: 0.0502, DiceLoss: 0.5708
# [Epoch 12 Step 30] CE: 0.0442, DiceLoss: 0.5633
# [Epoch 12 Step 40] CE: 0.1499, DiceLoss: 0.5695
# [Epoch 12 Step 50] CE: 0.1069, DiceLoss: 0.5893
# [Epoch 12 Step 60] CE: 0.0408, DiceLoss: 0.5330
# [Epoch 12 Step 70] CE: 0.0691, DiceLoss: 0.5525
# [Epoch 12 Step 80] CE: 0.0597, DiceLoss: 0.5772
# [Epoch 12 Step 90] CE: 0.0446, DiceLoss: 0.5660
# Epoch 12 TRAIN — CE: 0.0934, DiceLoss: 0.5855
# Epoch 12 VAL — liver Dice: 0.8950, tumor Dice: 0.0054
# Epoch 12 — liver Dice: 0.8950,tumor Dice:0.0054
# Epoch 12 mean Dice (liver+tumor): 0.4502
# [Epoch 13 Step 0] CE: 0.1348, DiceLoss: 0.5867
# [Epoch 13 Step 10] CE: 0.0314, DiceLoss: 0.5620
# [Epoch 13 Step 20] CE: 0.0444, DiceLoss: 0.5392
# [Epoch 13 Step 30] CE: 0.3343, DiceLoss: 0.5664
# [Epoch 13 Step 40] CE: 0.1042, DiceLoss: 0.5713
# [Epoch 13 Step 50] CE: 0.0455, DiceLoss: 0.5556
# [Epoch 13 Step 60] CE: 0.0384, DiceLoss: 0.5253
# [Epoch 13 Step 70] CE: 0.0421, DiceLoss: 0.5317
# [Epoch 13 Step 80] CE: 0.0535, DiceLoss: 0.5004
# [Epoch 13 Step 90] CE: 0.0346, DiceLoss: 0.5595
# Epoch 13 TRAIN — CE: 0.0717, DiceLoss: 0.5552
# Epoch 13 VAL — liver Dice: 0.9253, tumor Dice: 0.0730
# Epoch 13 — liver Dice: 0.9253,tumor Dice:0.0730
# Epoch 13 mean Dice (liver+tumor): 0.4991
# best_val_score: 0.4991345324204303
# [Epoch 14 Step 0] CE: 0.0807, DiceLoss: 0.5697
# [Epoch 14 Step 10] CE: 0.0311, DiceLoss: 0.5416
# [Epoch 14 Step 20] CE: 0.0376, DiceLoss: 0.5612
# [Epoch 14 Step 30] CE: 0.1066, DiceLoss: 0.6092
# [Epoch 14 Step 40] CE: 0.0298, DiceLoss: 0.5378
# [Epoch 14 Step 50] CE: 0.1694, DiceLoss: 0.6738
# [Epoch 14 Step 60] CE: 0.0951, DiceLoss: 0.5901
# [Epoch 14 Step 70] CE: 0.0837, DiceLoss: 0.5375
# [Epoch 14 Step 80] CE: 0.1170, DiceLoss: 0.5636
# [Epoch 14 Step 90] CE: 0.0251, DiceLoss: 0.5507
# Epoch 14 TRAIN — CE: 0.0771, DiceLoss: 0.5645
# Epoch 14 VAL — liver Dice: 0.9118, tumor Dice: 0.0417
# Epoch 14 — liver Dice: 0.9118,tumor Dice:0.0417
# Epoch 14 mean Dice (liver+tumor): 0.4767
# [Epoch 15 Step 0] CE: 0.0348, DiceLoss: 0.5099
# [Epoch 15 Step 10] CE: 0.0360, DiceLoss: 0.5566
# [Epoch 15 Step 20] CE: 0.0323, DiceLoss: 0.5489
# [Epoch 15 Step 30] CE: 0.0382, DiceLoss: 0.4858
# [Epoch 15 Step 40] CE: 0.0365, DiceLoss: 0.5525
# [Epoch 15 Step 50] CE: 0.1028, DiceLoss: 0.5577
# [Epoch 15 Step 60] CE: 0.0365, DiceLoss: 0.5432
# [Epoch 15 Step 70] CE: 0.0308, DiceLoss: 0.5455
# [Epoch 15 Step 80] CE: 0.0277, DiceLoss: 0.5559
# [Epoch 15 Step 90] CE: 0.0302, DiceLoss: 0.4730
# Epoch 15 TRAIN — CE: 0.0669, DiceLoss: 0.5466
# Epoch 15 VAL — liver Dice: 0.9167, tumor Dice: 0.1219
# Epoch 15 — liver Dice: 0.9167,tumor Dice:0.1219
# Epoch 15 mean Dice (liver+tumor): 0.5193
# best_val_score: 0.5192944192196591

# %%
@torch.no_grad()
def visualize_liver_and_tumor(filename="liver_tumor_1.png"):
    desktop = os.path.join(os.path.expanduser("~"), "Desktop")
    save_path = os.path.join(desktop, filename)

    model.eval()

   
    idx = random.randint(0, len(val_images) - 1)
    img = val_images[idx]
    lbl = val_labels[idx]
    img_patch, lbl_patch = get_random_patch(img, lbl, patch_size)

  
    x = img_patch.unsqueeze(0).to(device)          
    with torch.cuda.amp.autocast(enabled=(device.type == "cuda")):
        logits = model(x)
    pred = logits.argmax(1)[0].cpu().numpy()       

    img_np = img_patch[0].numpy()                 
    lbl_np = lbl_patch.numpy()                    
    d = img_np.shape[0] // 2
    ct = img_np[d]
    gt_slice = lbl_np[d]
    pr_slice = pred[d]
    gt_liver = (gt_slice == 1)
    gt_tumor = (gt_slice == 2)
    pr_liver = (pr_slice == 1)
    pr_tumor = (pr_slice == 2)


    gt_rgb = np.zeros((*ct.shape, 3), dtype=float)
    gt_rgb[gt_liver] = [0, 1, 0]   # green
    gt_rgb[gt_tumor] = [1, 0, 0]   # red

    pr_rgb = np.zeros((*ct.shape, 3), dtype=float)
    pr_rgb[pr_liver] = [0, 1, 0] 
    pr_rgb[pr_tumor] = [1, 0, 0]  

  
    fig, axes = plt.subplots(1, 3, figsize=(18, 8))

    axes[0].imshow(ct, cmap="gray")
    axes[0].set_title("CT")
    axes[0].axis("off")

    axes[1].imshow(ct, cmap="gray")
    axes[1].imshow(gt_rgb, alpha=0.4)
    axes[1].set_title("Ground Truth\nGreen=liver, Red=tumor")
    axes[1].axis("off")

    axes[2].imshow(ct, cmap="gray")
    axes[2].imshow(pr_rgb, alpha=0.4)
    axes[2].set_title("Prediction\nGreen=liver, Red=tumor")
    axes[2].axis("off")

    plt.tight_layout()
    plt.savefig(save_path, dpi=200)
    plt.close(fig)

# %%
for i in range(1, 6):
    visualize_liver_and_tumor(filename=f"liver_tumor_vis_{i}.png")
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_12060\2975121857.py:16: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=(device.type == "cuda")):
